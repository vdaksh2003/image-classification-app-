# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/ai-image-classifier/Scrappedimages(1)/Scrappedimages(1)/img1- (974).jpg
# /kaggle/input/ai-image-classifier/Scrappedimages(1)/Scrappedimages(1)/img1- (664).jpg
# /kaggle/input/ai-image-classifier/Scrappedimages(1)/Scrappedimages(1)/img1- (548).jpg
# /kaggle/input/ai-image-classifier/Scrappedimages(1)/Scrappedimages(1)/img1- (570).jpg
# /kaggle/input/ai-image-classifier/Scrappedimages(1)/Scrappedimages(1)/img1- (941).jpg
# /kaggle/input/ai-image-classifier/Scrappedimages(1)/Scrappedimages(1)/img1- (1063).jpg
# /kaggle/input/ai-image-classifier/Scrappedimages(1)/Scrappedimages(1)/img1- (770).jpg
# /kaggle/input/ai-image-classifier/Scrappedimages(1)/Scrappedimages(1)/img1- (765).jpg
# /kaggle/input/ai-image-classifier/Scrappedimages(1)/Scrappedimages(1)/img1- (1132).jpg
# /kaggle/input/ai-image-classifier/Scrappedimages(1)/Scrappedimages(1)/img1- (606).jpg
# /kaggle/input/ai-image-classifier/Scrappedimages(1)/Scrappedimages(1)/img1- (777).jpg
# ...

# %%
import os
import pandas as pd

images_folder = '/kaggle/input/ai-image-classifier/ScrappedImages(0)/ScrappedImages(0)'

data0 = []
t=0
for filename in os.listdir(images_folder):
    if filename.endswith('.jpg') or filename.endswith('.png'):  # Check for image file extensions
        image_id = filename  # You can modify this to create unique IDs if needed
        label = 0  # Set a default label; you can change this logic as per your need
        data0.append({'image_id': image_id, 'label': label})

df = pd.DataFrame(data0)

# %%
df
# Out:
#             image_id  label
# 0    img0- (433).jpg      0
# 1    img0- (741).jpg      0
# 2    img0- (615).jpg      0
# 3    img0- (442).jpg      0
# 4     img0- (15).jpg      0
# ..               ...    ...
# 771  img0- (326).jpg      0
# 772  img0- (322).jpg      0
# 773  img0- (747).jpg      0
# 774  img0- (193).jpg      0
# 775  img0- (558).jpg      0
#
# [776 rows x 2 columns]

# %%
import os
import pandas as pd


images_folder = '/kaggle/input/ai-image-classifier/Scrappedimages(1)/Scrappedimages(1)'

data1 = []
t=0
for filename in os.listdir(images_folder):
    if filename.endswith('.jpg') or filename.endswith('.png'):  # Check for image file extensions
        image_id = filename  # You can modify this to create unique IDs if needed
        label = 1  # Set a default label; you can change this logic as per your need
        data1.append({'image_id': image_id, 'label': label})

df2 = pd.DataFrame(data1)

df2.to_csv('/kaggle/working/images_labels.csv', index=False)

# %%
df2
# Out:
#              image_id  label
# 0     img1- (974).jpg      1
# 1     img1- (664).jpg      1
# 2     img1- (548).jpg      1
# 3     img1- (570).jpg      1
# 4     img1- (941).jpg      1
# ...               ...    ...
# 1157  img1- (983).jpg      1
# 1158  img1- (620).jpg      1
# 1159  img1- (569).jpg      1
# 1160  img1- (644).jpg      1
# 1161   img1- (30).jpg      1
#
# [1162 rows x 2 columns]

# %%
dff = pd.concat([df, df2], axis=0)

# Shuffle the combined dataset
dff = dff.sample(frac=1).reset_index(drop=True)

# %%
dff
# Out:
#               image_id  label
# 0      img1- (599).jpg      1
# 1     img1- (1099).jpg      1
# 2      img1- (579).jpg      1
# 3      img1- (816).jpg      1
# 4       img0- (41).jpg      0
# ...                ...    ...
# 1933    img0- (29).jpg      0
# 1934  img1- (1034).jpg      1
# 1935   img1- (169).jpg      1
# 1936   img1- (226).jpg      1
# 1937  img1- (1081).jpg      1
#
# [1938 rows x 2 columns]

# %%
s=dff['image_id'][1]

# %%
s
# Out:
# 'img1- (306).jpg'

# %%
dff
# Out:
#               image_id  label
# 0      img1- (185).jpg      1
# 1      img1- (306).jpg      1
# 2     img1- (1161).jpg      1
# 3      img0- (557).jpg      0
# 4       img0- (47).jpg      0
# ...                ...    ...
# 1933   img1- (300).jpg      1
# 1934   img1- (583).jpg      1
# 1935   img0- (169).jpg      0
# 1936  img1- (1079).jpg      1
# 1937   img1- (664).jpg      1
#
# [1938 rows x 2 columns]

# %%
dff['tensor']=dff['label']

# %%
dff
# Out:
#               image_id  label  tensor
# 0      img1- (599).jpg      1       1
# 1     img1- (1099).jpg      1       1
# 2      img1- (579).jpg      1       1
# 3      img1- (816).jpg      1       1
# 4       img0- (41).jpg      0       0
# ...                ...    ...     ...
# 1933    img0- (29).jpg      0       0
# 1934  img1- (1034).jpg      1       1
# 1935   img1- (169).jpg      1       1
# 1936   img1- (226).jpg      1       1
# 1937  img1- (1081).jpg      1       1
#
# [1938 rows x 3 columns]

# %%
for i in range(len(dff)):
    s=dff['image_id'][i]
    if dff.iloc[i]['label']==0:
        
        dff['tensor'][i]='/kaggle/input/ai-image-classifier/ScrappedImages(0)/ScrappedImages(0)/'+s
    else:
        dff['tensor'][i]= '/kaggle/input/ai-image-classifier/Scrappedimages(1)/Scrappedimages(1)/'+s
# Out:
# /tmp/ipykernel_34/2651763728.py:7: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   dff['tensor'][i]= '/kaggle/input/ai-image-classifier/Scrappedimages(1)/Scrappedimages(1)/'+s
# ...

# %%
df=pd.read_csv('/kaggle/input/pathdata/path.csv')

# %%
df
# Out:
#       Unnamed: 0          image_id  label  \
# 0              0  img1- (1068).jpg      1
# 1              1   img0- (262).jpg      0
# 2              2   img0- (102).jpg      0
# 3              3   img1- (297).jpg      1
# 4              4    img0- (54).jpg      0
# ...          ...               ...    ...
# 1933        1933   img1- (316).jpg      1
# 1934        1934   img0- (706).jpg      0
# 1935        1935   img1- (177).jpg      1
# 1936        1936   img1- (351).jpg      1
# 1937        1937   img0- (768).jpg      0
#
#                                                  tensor
# 0     /kaggle/input/ai-image-classifier/Scrappedimag...
# 1     /kaggle/input/ai-image-classifier/ScrappedImag...
# 2     /kaggle/input/ai-image-classifier/ScrappedImag...
# 3     /kaggle/input/ai-image-classifier/Scrappedimag...
# 4     /kaggle/input/ai-image-classifier/ScrappedImag...
# ...                                                 ...
# 1933  /kaggle/input/ai-image-classifier/Scrappedimag...
# ...

# %%
from PIL import Image

def load_image(image_path):
   
    img = Image.open(image_path)
    
    img_resized = img.resize((224, 224))
    
    
    image_array = np.array(img_resized)
    
    return image_array

# %%
import requests
import numpy as np
import cv2
from IPython.display import display, Image
from io import BytesIO

# %%
import pandas as pd
import numpy as np
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE


image_paths = df['tensor'].values
labels = df['label'].values


IMG_SIZE = 224
def load_images(image_paths):
    images = []
    for path in image_paths:
        image = cv2.imread(path)
        image = cv2.resize(image, (IMG_SIZE, IMG_SIZE))
        image = img_to_array(image)
        images.append(image)
    return np.array(images)

X = load_images(image_paths)
y = labels
X = X.astype('float32') / 255.0
y = np.array(y)

# %%
n_samples, width, height, n_channels = X.shape
X_flattened = X.reshape((n_samples, width * height * n_channels))
smote = SMOTE(random_state=42)
X_resampled_flattened, y_resampled = smote.fit_resample(X_flattened, y)
X_resampled = X_resampled_flattened.reshape((X_resampled_flattened.shape[0], width, height, n_channels))
X_train, X_val, y_train, y_val = train_test_split(X_resampled, y_resampled, test_size=0.2, random_state=42)

# %%
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.optimizers import Adam

# Load the pre-trained VGG16 model + higher level layers
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
for layer in base_model.layers:
    layer.trainable = False
x = Flatten()(base_model.output)
x = Dense(256, activation='relu')(x)
x = Dense(1, activation='sigmoid')(x)
model = Model(inputs=base_model.input, outputs=x)
model.compile(optimizer=Adam(learning_rate=0.0001), loss='binary_crossentropy', metrics=['precision','accuracy'])
# Out:
# ...
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

early_stopping = EarlyStopping(monitor='val_loss', patience=10, mode='min')
history = model.fit(
    X_train, y_train,
    epochs=50,
    batch_size=32,
    validation_data=(X_val, y_val),verbose=1,
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/50
#  1/59 ━━━━━━━━━━━━━━━━━━━━ 29:51 31s/step - accuracy: 0.5625 - loss: 0.7196 - precision: 0.4545
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1717381225.322860     140 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# W0000 00:00:1717381225.343340     140 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - accuracy: 0.6844 - loss: 0.6128 - precision: 0.6720
# W0000 00:00:1717381237.905487     140 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# W0000 00:00:1717381239.549580     138 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 64s 568ms/step - accuracy: 0.6858 - loss: 0.6106 - precision: 0.6736 - val_accuracy: 0.8409 - val_loss: 0.3882 - val_precision: 0.7899
# ...

# %%
model.summary()
# Out:
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 224, 224, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 112, 112, 128)  │        73,856 │
# ...

# %%
model.save_weights('/kaggle/working/aiimagemodel.weights.h5')

# %%
import cv2
import os
from tensorflow.keras.applications import InceptionV3

from tensorflow.keras.layers import Dense, Flatten, Dropout, GlobalAveragePooling2D
from tensorflow.keras.preprocessing.image import img_to_array
f


image_paths = df['tensor'].values
labels = df['label'].values
IMG_SIZE = 299 
def load_images(image_paths):
    images = []
    for path in image_paths:
        image = cv2.imread(path)
        image = cv2.resize(image, (IMG_SIZE, IMG_SIZE))
        image = img_to_array(image)
        images.append(image)
    return np.array(images)

X = load_images(image_paths)
y = labels
X = X.astype('float32') / 255.0
y = np.array(y)
smote = SMOTE()
X = X.reshape((X.shape[0], -1))  # Reshape for SMOTE
X_res, y_res = smote.fit_resample(X, y)
X_res = X_res.reshape((-1, IMG_SIZE, IMG_SIZE, 3))
X_train, X_test, y_train, y_test = train_test_split(X_res, y_res, test_size=0.2, random_state=42)

base_model = InceptionV3(weights='imagenet', include_top=False, input_shape=(IMG_SIZE, IMG_SIZE, 3))
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(256, activation='relu')(x)
#x = Dropout(0.5)(x)
predictions = Dense(1, activation='sigmoid')(x)
model = Model(inputs=base_model.input, outputs=predictions)
for layer in base_model.layers:
    layer.trainable = False

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy','precision'])
early_stopping = EarlyStopping(monitor='val_loss', patience=10, mode='min')
# Train the model
model.fit(X_train, y_train, epochs=20, batch_size=32, validation_data=(X_test, y_test),callbacks=early_stopping)

# Evaluate the model
# Out:
# Epoch 1/20
#  1/59 ━━━━━━━━━━━━━━━━━━━━ 12:21 13s/step - accuracy: 0.5000 - loss: 0.6638 - precision: 0.5357
# W0000 00:00:1717336549.401594     125 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.6580 - loss: 0.6394 - precision: 0.6577
# W0000 00:00:1717336560.207373     122 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# W0000 00:00:1717336567.200827     123 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 35s 387ms/step - accuracy: 0.6593 - loss: 0.6374 - precision: 0.6589 - val_accuracy: 0.8215 - val_loss: 0.4271 - val_precision: 0.8578
# Epoch 2/20
# W0000 00:00:1717336571.897167     122 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# ...

# %%
model.summary()
# Out:
# Model: "functional_7"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_3       │ (None, 299, 299,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_282 (Conv2D) │ (None, 149, 149,  │        864 │ input_layer_3[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 149, 149,  │         96 │ conv2d_282[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# ...

# %%
model.save('/kaggle/working/inceptionv3f.weights.h5')

# %%
df.to_csv('/kaggle/working/df.csv')
